# %%
import numpy as np
import pandas as pd
import player as p

# %%
data = pd.read_csv("AAPL.csv", usecols=[1,2,3,4,6,7,8])

# %%
data.head()
# Out:
#        Open      High       Low     Close       Volume    20_day    50_day
# 0  0.128348  0.128906  0.128348  0.128348  469033600.0  0.138588  0.132578
# 1  0.122210  0.122210  0.121652  0.121652  175884800.0  0.138979  0.132266
# 2  0.113281  0.113281  0.112723  0.112723  105728000.0  0.139732  0.132121
# 3  0.115513  0.116071  0.115513  0.115513   86441600.0  0.141071  0.132232
# 4  0.118862  0.119420  0.118862  0.118862   73449600.0  0.142215  0.132299

# %%
play = True

while (play):
    playerObj = p.Player('Apple',10000,{'Apple':0})
    turns = 1
    n_shares_bought = 0
    n_shares_sold = 0
    TotalShares = 0
    TotalCash = 0
    while turns <= 3:

        print(f"Player your Shares : {playerObj.portfolio} your Cash: {playerObj.cash}\n")
        print(f"Day {turns} apple stock: Open-->{float(data.iloc[turns][0])} \n")
        print(f"High-->{float(data.iloc[turns][1])} \n")
        print(f"Low-->{float(data.iloc[turns][2])} \n")
        print(f"Close-->{float(data.iloc[turns][3])} \n")
        print(f"Volume-->{float(data.iloc[turns][4])} \n")

        print("3 things you can do")
        print("1. Buy(B/b)  2. Sell(S/s) 3. Hold(H/h)\n")
        choice = input("what you want to do?!!!!\n")
        #str1 = 'Apple'+str(turns)
        stockObject = p.Stock('Apple',data.iloc[turns,0])

        if choice == 'S' or choice == 's':
            #stck = input("which stock you want to sell?")
            n_shares_sold = int(input("How many shares you want to sell--> "))
            if n_shares_sold > playerObj.portfolio['Apple']:
                print(f"Sorry you dont own that many stocks, Try again!!! \n")
                continue
            playerObj.sell(stockObject,int(n_shares_sold),'Apple')

        elif choice == 'B' or choice == 'b':
            n_shares_bought = int(input("How many shares you want to buy--> "))
            if (n_shares_bought * float(data.iloc[turns][0])) > playerObj.cash:
                print(f"Sorry you cant afford that many stocks, Try again!!! \n")
                continue
            playerObj.buy(stockObject,int(n_shares_bought))

        elif choice == 'H' or choice == 'h':
            turns+=1
            continue

        else:
            print("<<>><<>><<>>Enter Valid Choice<<>><<>><<>> \n")
            continue
        turns+=1


    TotalShares = sum(playerObj.portfolio.values()) 
    TotalCash = playerObj.cash+(TotalShares*data.iloc[turns,0])

    print(f"Player your shares : {playerObj.portfolio} your cash :{playerObj.cash} shares cost : {TotalShares*float(data.iloc[turns,0])}\n")

    if TotalCash > 10000:
        print(f"Congrats! you made profit of:{TotalCash - 10000}\n")
    elif TotalCash < 10000:
        print(f"Oh No! you lost :{10000 - TotalCash}\n")
    else:
        print(f"No profit/ loss\n")

    print(f"Game end\n")
    print(f"<><><><><><><><><><><><><><><><><><>\n")
    
   
    while True:
      try:
        stillPlay = input("Want to play again!! Enter Y/y or N/n: ")
        if stillPlay == "y" or stillPlay == "Y":
            play = True
            break
        elif stillPlay == "n" or stillPlay == "N":
            play = False
            break
        else:
            print(f"Enter Valid choice\n")  
      except:
            continue

print("Thanks For Playing Game!!")
# Out:
# Player your Shares : {'Apple': 0} your Cash: 10000
#
# Day 1 apple stock: Open-->0.12220999999999999
#
# High-->0.12220999999999999
#
# Low-->0.121652
#
# Close-->0.121652
#
# Volume-->175884800.0
#
# 3 things you can do
# 1. Buy(B/b)  2. Sell(S/s) 3. Hold(H/h)
#
# what you want to do?!!!!
# b
# How many shares you want to buy--> 2000000000000
# Sorry you cant afford that many stocks, Try again!!!
#
# Player your Shares : {'Apple': 0} your Cash: 10000
#
# Day 1 apple stock: Open-->0.12220999999999999
#
# High-->0.12220999999999999
#
# Low-->0.121652
#
# Close-->0.121652
#
# Volume-->175884800.0
#
# 3 things you can do
# 1. Buy(B/b)  2. Sell(S/s) 3. Hold(H/h)
#
# what you want to do?!!!!
# s
# How many shares you want to sell--> 2
# Sorry you dont own that many stocks, Try again!!!
#
# Player your Shares : {'Apple': 0} your Cash: 10000
#
# Day 1 apple stock: Open-->0.12220999999999999
#
# High-->0.12220999999999999
#
# Low-->0.121652
#
# Close-->0.121652
#
# Volume-->175884800.0
#
# 3 things you can do
# 1. Buy(B/b)  2. Sell(S/s) 3. Hold(H/h)
#
# what you want to do?!!!!
# h
# Player your Shares : {'Apple': 0} your Cash: 10000
#
# Day 2 apple stock: Open-->0.11328099999999999
#
# High-->0.11328099999999999
#
# Low-->0.112723
#
# Close-->0.112723
#
# Volume-->105728000.0
#
# 3 things you can do
# 1. Buy(B/b)  2. Sell(S/s) 3. Hold(H/h)
#
# what you want to do?!!!!
# h
# Player your Shares : {'Apple': 0} your Cash: 10000
#
# Day 3 apple stock: Open-->0.115513
#
# High-->0.11607100000000001
#
# Low-->0.115513
#
# Close-->0.115513
#
# Volume-->86441600.0
#
# 3 things you can do
# 1. Buy(B/b)  2. Sell(S/s) 3. Hold(H/h)
#
# what you want to do?!!!!
# h
# Player your shares : {'Apple': 0} your cash :10000 shares cost : 0.0
#
# No profit/ loss
#
# Game end
#
# <><><><><><><><><><><><><><><><><><>
#
# Want to play again!! Enter Y/y or N/n:
# n
# Thanks For Playing Game!!

# %%
stockObject = p.Stock('Apple',data.iloc[turns,0])

# %%
stockObject.ticker
# Out:
# 'Apple'

# %%
(float(data.iloc[1,0]))
# Out:
# 0.12220999999999999
